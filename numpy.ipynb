# %%
import numpy as np

# %% [markdown]
# # Data Types & Attributes

# %% [markdown]
# ## numpy's main datatype is ndarray

# %%
a1= np.array([1,2,3])
al
# Out:
# array([1, 2, 3])

# %%
type(a1)
# Out:
# numpy.ndarray

# %% [markdown]
# ![2024-01-20.png](attachment:2024-01-20.png)

# %%
a2= np.array([[1,2,3],
             [4,3,5.4]])
a2
# Out:
# array([[1. , 2. , 3. ],
#        [4. , 3. , 5.4]])

# %%
a1.shape
# Out:
# (3,)

# %%
a2.shape
# Out:
# (2, 3)

# %%
a3 = np.array([[[2,4,7],
                [1,3.4,5],
                [1.2,43,5]],
                
                [[2,4,2],
                 [3,2,4],
                 [5,7,8]]])
a3
# Out:
# array([[[ 2. ,  4. ,  7. ],
#         [ 1. ,  3.4,  5. ],
#         [ 1.2, 43. ,  5. ]],
#
#        [[ 2. ,  4. ,  2. ],
#         [ 3. ,  2. ,  4. ],
#         [ 5. ,  7. ,  8. ]]])

# %%
a3.shape
# Out:
# (2, 3, 3)

# %%
a1.ndim, a2.ndim, a3.ndim # no of dimensions
# Out:
# (1, 2, 3)

# %%
a1.dtype, a2.dtype, a3.dtype
# Out:
# (dtype('int32'), dtype('float64'), dtype('float64'))

# %%
a1.size, a2.size, a3.size
# Out:
# (3, 6, 18)

# %%
type(a1), type(a2), type(a3)
# Out:
# (numpy.ndarray, numpy.ndarray, numpy.ndarray)

# %%
# create a dataframe from numoy array
import pandas as pd
df = pd.DataFrame(a2)
df
# Out:
#      0    1    2
# 0  1.0  2.0  3.0
# 1  4.0  3.0  5.4

# %% [markdown]
# ## 2. Creating Arrays

# %%
ones = np.ones((2,3))
ones, ones.dtype
# Out:
# (array([[1., 1., 1.],
#         [1., 1., 1.]]),
#  dtype('float64'))
